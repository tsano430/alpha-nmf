# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-2.5, 2.5 + 0.1, 0.2)
alg_name = ["MUR", "NT", "Proposed"]

# %% [markdown]
# ORL dataset
# ---------------

# %%
df1 = pd.read_csv("../src/log/ret_orl.log")
df1
# Out:
#      -2.5   -2.3    -2.1    -1.9    -1.7    -1.5    -1.3    -1.1    -0.9  \
# 0  1061.0  953.8  1278.6  1964.4  1616.6  1884.6  1452.2  1567.6  1376.8
# 1   195.6  179.0   183.0   200.2   195.2   220.4   213.2   215.6   214.0
# 2   205.2  207.0   214.2   217.8   222.0   227.8   264.8   231.8   227.6
#
#      -0.7  ...     0.7     0.9     1.1     1.3     1.5     1.7     1.9  \
# 0  1265.8  ...  1296.0  1300.4  1318.4  1339.0  1389.0  1512.6  1591.0
# 1   223.6  ...   229.6   219.6   266.6   234.8   217.6   199.2   212.8
# 2   258.6  ...   286.6   258.4   237.8   254.0   274.0   239.8   255.4
#
#       2.1     2.3     2.5
# 0  1722.2  2000.0  1637.6
# 1   206.0   185.8   173.8
# 2   243.6   214.2   204.2
#
# [3 rows x 26 columns]

# %%
for i in range(len(df1)):
    y = df1.iloc[i]
    plt.plot(x, y, label=alg_name[i])
    
plt.xticks(np.arange(-2.5, 2.5 + 0.1, 1.0))
plt.xlabel("Alpha", fontsize=18)
plt.ylabel("Time (sec)", fontsize=18)
plt.tick_params(labelsize=16)
plt.legend(fontsize=16, loc='upper right', borderaxespad=1)
plt.savefig("./ret_orl.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# CLUTO (tr23) dataset
# ----------------------------

# %%
df2 = pd.read_csv("../src/log/ret_cluto.log")
df2
# Out:
#     -2.5   -2.3   -2.1    -1.9   -1.7   -1.5   -1.3   -1.1   -0.9   -0.7  ...  \
# 0  736.0  696.2  757.4  1057.2  800.4  659.6  648.6  632.4  537.6  651.4  ...
# 1   80.6   84.6   82.6    81.6   86.0   71.2   68.6   67.0   41.0   47.8  ...
# 2  123.6  135.6  117.0   128.6  151.0   81.6  114.4   60.4   54.4   69.2  ...
#
#      0.7    0.9    1.1    1.3    1.5    1.7    1.9    2.1    2.3    2.5
# 0   73.6  220.6  202.0  277.6  280.2  308.6  283.0  255.4  368.2  356.0
# 1   72.0   67.6   65.4   87.0   99.6  145.2  206.2  310.2  465.6  880.6
# 2  146.2  144.0  142.4  172.6  175.8  190.4  171.4  242.4  192.6  242.8
#
# [3 rows x 26 columns]

# %%
for i in range(len(df2)):
    y = df2.iloc[i]
    plt.plot(x, y, label=alg_name[i])
    
plt.xticks(np.arange(-2.5, 2.5 + 0.1, 1.0))
plt.xlabel("Alpha", fontsize=18)
plt.ylabel("Time (sec)", fontsize=18)
plt.tick_params(labelsize=16)
plt.legend(fontsize=16, loc='upper right', borderaxespad=1)
plt.savefig("./ret_cluto.png", bbox_inches="tight")
plt.show()
