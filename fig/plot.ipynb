# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-2.5, 2.5 + 0.1, 0.2)
alg_name = ["MUR", "NT", "Proposed"]

# %% [markdown]
# ORL dataset
# ---------------

# %%
df1 = pd.read_csv("../src/log/ret_orl.log")
df1
# Out:
#      -2.5   -2.3    -2.1    -1.9    -1.7    -1.5    -1.3    -1.1    -0.9  \
# 0  1051.6  944.8  1266.2  1940.4  1599.2  1869.4  1439.6  1553.0  1364.4
# 1   195.6  178.8   182.6   199.6   194.4   220.0   213.2   214.8   213.8
# 2   217.6  231.0   235.8   247.0   248.6   265.6   267.2   267.0   267.6
#
#      -0.7  ...     0.7     0.9     1.1     1.3     1.5     1.7     1.9  \
# 0  1254.2  ...  1289.2  1296.4  1311.2  1335.2  1388.0  1505.4  1588.4
# 1   223.2  ...   229.4   219.8   267.0   235.0   219.4   199.4   213.6
# 2   268.8  ...   263.6   282.0   296.2   284.2   295.0   306.4   264.8
#
#       2.1     2.3     2.5
# 0  1717.6  1993.4  1633.6
# 1   206.0   185.8   173.8
# 2   231.4   221.4   222.4
#
# [3 rows x 26 columns]

# %%
for i in range(len(df1)):
    y = df1.iloc[i]
    plt.plot(x, y, label=alg_name[i])
    
plt.xticks(np.arange(-2.5, 2.5 + 0.1, 1.0))
plt.xlabel("Alpha", fontsize=18)
plt.ylabel("Time (sec)", fontsize=18)
plt.tick_params(labelsize=16)
plt.legend(fontsize=16, loc='upper right', borderaxespad=1)
plt.savefig("./ret_orl.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# CLUTO (tr23) dataset
# ----------------------------

# %%
df2 = pd.read_csv("../src/log/ret_cluto.log")
df2
# Out:
#     -2.5   -2.3   -2.1    -1.9   -1.7   -1.5   -1.3   -1.1   -0.9   -0.7  ...  \
# 0  738.4  696.4  757.6  1056.0  800.2  661.8  649.4  634.2  538.0  652.4  ...
# 1   80.6   84.4   82.6    81.4   86.0   71.4   68.6   67.8   41.0   47.8  ...
# 2   93.6  100.2   95.4    98.8  109.6   86.0   81.6   80.0   44.0   52.6  ...
#
#     0.7    0.9    1.1    1.3    1.5    1.7    1.9    2.1    2.3    2.5
# 0  74.0  221.6  203.6  279.4  283.6  310.4  284.8  257.4  371.2  358.4
# 1  72.4   68.0   65.8   87.2  100.2  146.4  207.6  312.4  468.6  886.8
# 2  91.6   92.2  106.2   91.4  130.0  100.6  107.0  104.6  152.6  184.8
#
# [3 rows x 26 columns]

# %%
for i in range(len(df2)):
    y = df2.iloc[i]
    plt.plot(x, y, label=alg_name[i])
    
plt.xticks(np.arange(-2.5, 2.5 + 0.1, 1.0))
plt.xlabel("Alpha", fontsize=18)
plt.ylabel("Time (sec)", fontsize=18)
plt.tick_params(labelsize=16)
plt.legend(fontsize=16, loc='upper right', borderaxespad=1)
plt.savefig("./ret_cluto.png", bbox_inches="tight")
plt.show()
